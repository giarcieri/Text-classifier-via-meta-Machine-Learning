# %% [markdown]
# **Task**
# 1. Build and test a text classifier based on the age of a user according their age classes (0-10, 11-20, 21-30, 31+).
#
# 2. Build a ML name classifier that classifies the age of a user according their age classes (0-10, 11-20, 21-30, 31+).
#
# 3. Build a meta classifier that combines the previously built classifiers based on their age classes (0-10, 11-20, 21-30, 31+).

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB as bayes
from sklearn.feature_extraction.text import CountVectorizer as countvec
from sklearn.metrics import accuracy_score as accuracy
from sklearn.ensemble import RandomForestClassifier 
import random
random.seed(0)

# %%
# Import data and show some information
data = pd.read_pickle('./twitterData.pkl')
print(data.shape)
data.head(10)
# Out:
# (2916, 6)
#        screen_name              name  \
# 0        DatZerooo             David
# 0          reap705       Oliver Gast
# 0      Dossary1995  Khalid Aldossary
# 0          eduUu06             eduUu
# 0   Narutofreak935           Avengar
# 0      miley_sarah             Sarah
# 0       DerIncubus       Der Incubus
# 0         Petouser   ペトユサ (Petoyusa)
# 0    ChrisWhite126       Chris White
# 0  MusicFreakFever         Nadine (:
#
#                                  tweets_concatenated  \
# 0  Warum riecht mein Bruder nach Pizza wenn er ei...
# 0  [CSS] Ein Off-canvas-Menü mit Dropdown-Navigat...
# 0
# 0  heut abend kogge und morgen endlich haare ab :...
# 0  @GrandlineTV gib nicht auf und mach dein Ding ...
# 0  RT @bomelino: Das "Backe, backe Kuchen"-Lied i...
# 0  @NicoleAllm Na ... gut ins neue Jahr gestartet...
# 0  Verschwörungstheorie: Pokemon Go wird von der ...
# 0  Ach du scheiße ist das warm. :( Hab locker 5kg...
# 0  Heute nur DREI (!) Schulstunden !\n Ich LIIIIE...
#
#                                           avatar_url gender   age
# 0  http://pbs.twimg.com/profile_images/7569661512...      M  16.0
# 0  http://pbs.twimg.com/profile_images/1366984169...      M  15.0
# 0  http://pbs.twimg.com/profile_images/4167523242...      M  37.0
# 0  http://pbs.twimg.com/profile_images/896480580/...      M  46.0
# 0  http://pbs.twimg.com/profile_images/7317971734...      F  19.0
# 0  http://pbs.twimg.com/profile_images/7584397626...      M  18.0
# 0  http://pbs.twimg.com/profile_images/5808649200...      F  22.0
# 0  http://pbs.twimg.com/profile_images/6626943925...      M  26.0
# 0  http://pbs.twimg.com/profile_images/6463341220...      M  37.0
# 0  http://pbs.twimg.com/profile_images/3788000003...      M  15.0

# %%
# Remove instances without tweets information
data[data['tweets_concatenated'] == ''].shape
# Out:
# (430, 6)

# %%
data = data[data['tweets_concatenated'] != '']
data.shape
# Out:
# (2486, 6)

# %%
# Remove instances without age information
data.isnull().sum()
# Out:
# screen_name               0
# name                      0
# tweets_concatenated       0
# avatar_url                0
# gender                    0
# age                    1349
# dtype: int64

# %%
data.dropna(subset=['age'], inplace=True)
data
# Out:
#         screen_name                 name  \
# 0         DatZerooo                David
# 0           reap705          Oliver Gast
# 0           eduUu06                eduUu
# 0    Narutofreak935              Avengar
# 0       miley_sarah                Sarah
# ..              ...                  ...
# 0   tinamuellerluge          Tina Müller
# 0     charmingLiisa                Liisa
# 0        MajaSpecht          Maja Specht
# 0     GabiHillerOhm  Gabriele Hiller-Ohm
# 0        batikordie         NIÑA COLADA.
#
#                                   tweets_concatenated  \
# 0   Warum riecht mein Bruder nach Pizza wenn er ei...
# 0   [CSS] Ein Off-canvas-Menü mit Dropdown-Navigat...
# 0   heut abend kogge und morgen endlich haare ab :...
# 0   @GrandlineTV gib nicht auf und mach dein Ding ...
# 0   RT @bomelino: Das "Backe, backe Kuchen"-Lied i...
# ..                                                ...
# 0   RT @sportDland: Da hört ihr's: Gebt alles! 💪\n...
# 0   @Frau_Dokta &lt;3||"Das Jahrhundert des Le Cor...
# 0                         😍😍 http://t.co/c6lb259T67||
# 0   Guten Morgen aus der Hansestadt.||Nachtwanderu...
# 0   ich brauche das kylie birthdaykit so dringend....
#
#                                            avatar_url gender   age
# 0   http://pbs.twimg.com/profile_images/7569661512...      M  16.0
# 0   http://pbs.twimg.com/profile_images/1366984169...      M  15.0
# 0   http://pbs.twimg.com/profile_images/896480580/...      M  46.0
# 0   http://pbs.twimg.com/profile_images/7317971734...      F  19.0
# 0   http://pbs.twimg.com/profile_images/7584397626...      M  18.0
# ..                                                ...    ...   ...
# 0   http://pbs.twimg.com/profile_images/6793113826...      M  16.0
# 0   http://pbs.twimg.com/profile_images/6470215469...      F  51.0
# 0   http://pbs.twimg.com/profile_images/6003719710...      F  18.0
# 0   http://pbs.twimg.com/profile_images/6498112476...      F  63.0
# 0   http://pbs.twimg.com/profile_images/5973146130...      F  14.0
#
# [1137 rows x 6 columns]

# %%
# Group users in age classes by replacing: (0-10) = 0, (11-20) = 1, (21-30) = 2, (31+) = 3 
data['age'] = np.where(data['age'].between(0,11), 0, data['age'])
data['age'] = np.where(data['age'].between(11,21), 1, data['age'])
data['age'] = np.where(data['age'].between(21,31), 2, data['age'])
data['age'] = np.where(data['age'].between(31,100), 3, data['age'])
data
# Out:
#         screen_name                 name  \
# 0         DatZerooo                David
# 0           reap705          Oliver Gast
# 0           eduUu06                eduUu
# 0    Narutofreak935              Avengar
# 0       miley_sarah                Sarah
# ..              ...                  ...
# 0   tinamuellerluge          Tina Müller
# 0     charmingLiisa                Liisa
# 0        MajaSpecht          Maja Specht
# 0     GabiHillerOhm  Gabriele Hiller-Ohm
# 0        batikordie         NIÑA COLADA.
#
#                                   tweets_concatenated  \
# 0   Warum riecht mein Bruder nach Pizza wenn er ei...
# 0   [CSS] Ein Off-canvas-Menü mit Dropdown-Navigat...
# 0   heut abend kogge und morgen endlich haare ab :...
# 0   @GrandlineTV gib nicht auf und mach dein Ding ...
# 0   RT @bomelino: Das "Backe, backe Kuchen"-Lied i...
# ..                                                ...
# 0   RT @sportDland: Da hört ihr's: Gebt alles! 💪\n...
# 0   @Frau_Dokta &lt;3||"Das Jahrhundert des Le Cor...
# 0                         😍😍 http://t.co/c6lb259T67||
# 0   Guten Morgen aus der Hansestadt.||Nachtwanderu...
# 0   ich brauche das kylie birthdaykit so dringend....
#
#                                            avatar_url gender  age
# 0   http://pbs.twimg.com/profile_images/7569661512...      M  1.0
# 0   http://pbs.twimg.com/profile_images/1366984169...      M  1.0
# 0   http://pbs.twimg.com/profile_images/896480580/...      M  3.0
# 0   http://pbs.twimg.com/profile_images/7317971734...      F  1.0
# 0   http://pbs.twimg.com/profile_images/7584397626...      M  1.0
# ..                                                ...    ...  ...
# 0   http://pbs.twimg.com/profile_images/6793113826...      M  1.0
# 0   http://pbs.twimg.com/profile_images/6470215469...      F  3.0
# 0   http://pbs.twimg.com/profile_images/6003719710...      F  1.0
# 0   http://pbs.twimg.com/profile_images/6498112476...      F  3.0
# 0   http://pbs.twimg.com/profile_images/5973146130...      F  1.0
#
# [1137 rows x 6 columns]

# %%
data['age'] = data['age'].astype('int')
data
# Out:
#         screen_name                 name  \
# 0         DatZerooo                David
# 0           reap705          Oliver Gast
# 0           eduUu06                eduUu
# 0    Narutofreak935              Avengar
# 0       miley_sarah                Sarah
# ..              ...                  ...
# 0   tinamuellerluge          Tina Müller
# 0     charmingLiisa                Liisa
# 0        MajaSpecht          Maja Specht
# 0     GabiHillerOhm  Gabriele Hiller-Ohm
# 0        batikordie         NIÑA COLADA.
#
#                                   tweets_concatenated  \
# 0   Warum riecht mein Bruder nach Pizza wenn er ei...
# 0   [CSS] Ein Off-canvas-Menü mit Dropdown-Navigat...
# 0   heut abend kogge und morgen endlich haare ab :...
# 0   @GrandlineTV gib nicht auf und mach dein Ding ...
# 0   RT @bomelino: Das "Backe, backe Kuchen"-Lied i...
# ..                                                ...
# 0   RT @sportDland: Da hört ihr's: Gebt alles! 💪\n...
# 0   @Frau_Dokta &lt;3||"Das Jahrhundert des Le Cor...
# 0                         😍😍 http://t.co/c6lb259T67||
# 0   Guten Morgen aus der Hansestadt.||Nachtwanderu...
# 0   ich brauche das kylie birthdaykit so dringend....
#
#                                            avatar_url gender  age
# 0   http://pbs.twimg.com/profile_images/7569661512...      M    1
# 0   http://pbs.twimg.com/profile_images/1366984169...      M    1
# 0   http://pbs.twimg.com/profile_images/896480580/...      M    3
# 0   http://pbs.twimg.com/profile_images/7317971734...      F    1
# 0   http://pbs.twimg.com/profile_images/7584397626...      M    1
# ..                                                ...    ...  ...
# 0   http://pbs.twimg.com/profile_images/6793113826...      M    1
# 0   http://pbs.twimg.com/profile_images/6470215469...      F    3
# 0   http://pbs.twimg.com/profile_images/6003719710...      F    1
# 0   http://pbs.twimg.com/profile_images/6498112476...      F    3
# 0   http://pbs.twimg.com/profile_images/5973146130...      F    1
#
# [1137 rows x 6 columns]

# %%
# Split the data into two trainings (trainSub, trainMeta) and one test set (test)
trainSub, tempData = train_test_split(data, test_size=0.4)
trainMeta, test = train_test_split(tempData, test_size=0.4)
print(trainSub.shape, trainMeta.shape, test.shape)
# Out:
# (682, 6) (273, 6) (182, 6)

# %%
# Extract tweets and names from the data
trainSub_tweets = trainSub['tweets_concatenated']
trainMeta_tweets = trainMeta['tweets_concatenated']
test_tweets = test['tweets_concatenated']
trainSub_names = trainSub['name']
trainMeta_names = trainMeta['name']
test_names = test['name']

# %%
# Extract the target column for each dataset
y_trainSub = trainSub['age']
y_trainMeta = trainMeta['age']
y_test = test['age']

# %%
trainSub_tweets.head(10)
# Out:
# 0    Seid glücklich mit dem was ihr habt. Und forde...
# 0    morgen nach polen &lt;3||hat im moment keine w...
# 0    @DHLPaket Jetzt ja, Karte kam heute nun auch p...
# 0    @Berndtdasbrot auweia :D||@Berndtdasbrot armer...
# 0    Ärger über Samsung - das wars! Bis auf weitere...
# 0    http://www.sat1.de/filme_serien/ncis/video/gan...
# 0    ICH BIN SCHARF http://t.co/AEdEJDu||FREAK in m...
# 0    @iBlali ohmein gott du passt dich dem Boden an...
# 0    Habe nun eine Ps4. Wer mich gerne adden will P...
# 0    @dagibeee ach dagi ist echt scheiße aber du mu...
# Name: tweets_concatenated, dtype: object

# %%
y_trainSub.head(10)
# Out:
# 0    0
# 0    1
# 0    2
# 0    1
# 0    3
# 0    3
# 0    1
# 0    1
# 0    2
# 0    1
# Name: age, dtype: int32

# %%
# 1. Build and test a text classifier based on the age of a user according their age classes (0-10, 11-20, 21-30, 31+)

# ML models don't recognize "tweets", so we need to apply a Bag of words in order to vectorize the words in the tweets and apply our model to this new dataset.
# This 'submodel' will provide the first stack of training and testing data for the final meta ML model.

# %%
# Use a Bag of Words Approach and train a classification model on trainSub_tweets
countvectorize_tweets = countvec()
X_trainSub_tweets = countvectorize_tweets.fit_transform(trainSub_tweets)
X_trainMeta_tweets = countvectorize_tweets.transform(trainMeta_tweets)
X_test_tweets = countvectorize_tweets.transform(test_tweets)

# %%
bayes_tweets = bayes()
bayes_tweets.fit(X_trainSub_tweets, y_trainSub)
tweet_score = bayes_tweets.score(X_test_tweets, y_test)

# %%
tweetScore_text = "Tweet SCore is {:0.2%}".format(tweet_score)
print(tweetScore_text)
# Out:
# Tweet SCore is 65.38%

# %%
stacked_input1 = pd.Series(bayes_tweets.predict(X_trainMeta_tweets))
stacked_input1_test = pd.Series(bayes_tweets.predict(X_test_tweets))

# %%
# 2. Build a ML name classifier that classifies the age of a user according their age classes (0-10, 11-20, 21-30, 31+)

# Similar to the text classifier, we train a model on our names.
# This submodel will provide the second stack of training and testing data for the final meta ML model

# %%
cvectorizer_names = countvec()
x_trainSub_names = cvectorizer_names.fit_transform(trainSub_names)

x_trainMeta_names = cvectorizer_names.transform(trainMeta_names)
x_test_names = cvectorizer_names.transform(test_names)

cvectorizer_names.get_feature_names()
# Out:
# ['18',
#  '19blockbuster97',
#  '1pundplays',
#  '_rudi_',
#  'abrell',
#  'achtelik',
#  'addi',
#  'adrian',
#  'aka',
#  'alawehayyealawe',
#  'alber',
#  'alex',
#  'alexander',
#  'alfath',
#  'alfred',
#  'aliiiina',
#  'alina',
#  'alt',
#  'alysha',
#  'ameri',
#  'ami',
#  'amir',
#  'amy',
#  'anastasia',
#  'andi',
#  'andrea',
#  'andreas',
#  'andré',
#  'angelina',
#  'anica',
#  'anika',
#  'anime',
#  'anissa',
#  'anja',
#  'anke',
#  'ann',
#  'anna',
#  'annastasia',
#  'anne',
#  'annelise',
#  'annika',
#  'antonia',
#  'antonio',
#  'arina',
#  'armin',
#  'armstrong',
#  'arrogant',
#  'art',
#  'auer',
#  'augustina',
#  'aull',
#  'aus',
#  'baerbel',
#  'baghouz',
#  'bakaï',
#  'bambina',
#  'barkeeper',
#  'baron',
#  'bassilicum',
#  'bayfidan',
#  'bea',
#  'becci',
#  'bee',
#  'behn',
#  'believe',
#  'ben',
#  'benjamin',
#  'benny',
#  'berger',
#  'berkiix3',
#  'bernd',
#  'berschick',
#  'bianca',
#  'bibi',
#  'birger',
#  'blaha',
#  'blanco',
#  'bloch',
#  'blog',
#  'bluehair',
#  'bluhm',
#  'blume',
#  'boy',
#  'brandon',
#  'brauer',
#  'braun',
#  'brendler',
#  'brini',
#  'britta',
#  'bronut',
#  'brown',
#  'brunhöfer',
#  'bruno',
#  'bruns',
#  'bubbbletea',
#  'bubblemc',
#  'budde',
#  'burak',
#  'bushido',
#  'bérnért',
#  'böhme',
#  'canan',
#  'candy',
#  'canning',
#  'capote',
#  'carla',
#  'carlos',
#  'carolin',
#  'carolina',
#  'casandra',
#  'cecewsbam',
#  'celina',
#  'chantal',
#  'charly',
#  'chellie',
#  'chris',
#  'chrissi',
#  'christian',
#  'christin',
#  'christina',
#  'cindy',
#  'cirillo',
#  'clara',
#  'claudia',
#  'claus',
#  'clown',
#  'colada',
#  'coralinart',
#  'costa',
#  'counterchupz',
#  'croxasworld',
#  'da',
#  'dade',
#  'daekoelschefetz',
#  'dalton',
#  'danger',
#  'daniel',
#  'daniele',
#  'daniele408',
#  'dannehl',
#  'darhaka',
#  'darkloli',
#  'darko',
#  'darkus',
#  'das',
#  'david',
#  'de',
#  'dean',
#  'degen',
#  'denis',
#  'denise',
#  'dennis',
#  'der',
#  'derzokerlp',
#  'diaby',
#  'die',
#  'dietrich',
#  'dilara',
#  'dins',
#  'directioner',
#  'diwo',
#  'dj',
#  'doganay',
#  'domenic',
#  'dominik',
#  'doppelnull',
#  'doruk',
#  'dr',
#  'drechsler',
#  'drefahl',
#  'drießen',
#  'drobný',
#  'dunia',
#  'dygryn',
#  'eberhardt',
#  'ebert',
#  'edler',
#  'eduuu',
#  'effing',
#  'eggerstedt',
#  'eikelboom',
#  'eisele',
#  'eisprinzessin',
#  'elaine',
#  'elena',
#  'elephant',
#  'elsner',
#  'enge',
#  'engel',
#  'enlil',
#  'eric',
#  'erik',
#  'es',
#  'estevao',
#  'eugen',
#  'eve',
#  'fabi',
#  'fabian',
#  'fabrycy',
#  'fan',
#  'farades',
#  'fazor',
#  'febriarno',
#  'fehr',
#  'feldmann',
#  'ferreira',
#  'feyme',
#  'fichtner',
#  'fieseler',
#  'fikra',
#  'firnwald',
#  'fischer',
#  'fitos',
#  'fleer',
#  'flex',
#  'flo',
#  'florian',
#  'flossdorf',
#  'fly',
#  'folcz',
#  'fortytwo',
#  'frances',
#  'franizzi',
#  'frank',
#  'franzi',
#  'franziska',
#  'freddy',
#  'freie',
#  'fresz',
#  'friedenslamm',
#  'fritsch',
#  'gabrielpbc',
#  'gast',
#  'geisenberger',
#  'genki',
#  'gerbig',
#  'gerd',
#  'germangamerhd',
#  'ghost',
#  'gianni',
#  'giik',
#  'gillissen',
#  'gitie',
#  'gladwish',
#  'glen',
#  'goehlert',
#  'gomez',
#  'gonzález',
#  'gordie',
#  'gottschalk',
#  'gr33nbl00d',
#  'greve',
#  'grießhammer',
#  'grizzlybaer90',
#  'grothe',
#  'gruber',
#  'grunewald',
#  'gräwe',
#  'guardex99',
#  'gunnar',
#  'haafidbou',
#  'haberstroh',
#  'hagen',
#  'haitah',
#  'hamann',
#  'hamburger',
#  'hamstercrack',
#  'hanna',
#  'hannah',
#  'hanneken',
#  'harriett',
#  'harry',
#  'hasenpflug',
#  'hasselbring',
#  'haus',
#  'hebel',
#  'heike',
#  'heiko',
#  'heinold',
#  'heinrich',
#  'heinrichs',
#  'heinz',
#  'helene',
#  'heller',
#  'hennings',
#  'henny',
#  'henryk',
#  'herbert',
#  'herondale',
#  'herr',
#  'herrmann',
#  'herzog',
#  'highlig',
#  'hirnlos',
#  'hit_nic',
#  'hobusch',
#  'holger',
#  'holtkamp',
#  'horan',
#  'horn',
#  'horst',
#  'hosenberg',
#  'houston',
#  'http',
#  'huber',
#  'huecking',
#  'hutchison',
#  'häusers',
#  'höcker',
#  'hönig',
#  'hübenet',
#  'hülsmann',
#  'ibrahim',
#  'ichvonne',
#  'incubus',
#  'inga',
#  'ingo',
#  'irina',
#  'isa',
#  'isabell',
#  'isabelle',
#  'isra',
#  'iv',
#  'ivanov',
#  'izuku',
#  'jack',
#  'jacky',
#  'jan',
#  'jana',
#  'janina',
#  'janine',
#  'janis',
#  'jannik',
#  'janny',
#  'janssen',
#  'jasmin',
#  'jasmina',
#  'jasnoch',
#  'jeff',
#  'jennifer',
#  'jenny',
#  'jens',
#  'jeremy',
#  'jessi',
#  'jessica',
#  'joe',
#  'johanna',
#  'johannes',
#  'jonas',
#  'josef',
#  'josie',
#  'jule',
#  'jules',
#  'julian',
#  'jung',
#  'justtrintex',
#  'jörg',
#  'jürgen',
#  'ka',
#  'kai',
#  'kamerunkultur',
#  'kargar',
#  'karina',
#  'karl',
#  'karolin',
#  'karoline',
#  'karsten',
#  'kasitv',
#  'kaspari',
#  'kate',
#  'kathi',
#  'kathrin',
#  'katja',
#  'kay',
#  'kayisi',
#  'kazim',
#  'kelbel',
#  'kelessidou',
#  'keller',
#  'keno',
#  'kern',
#  'kessy_san',
#  'kevin',
#  'ki',
#  'kiiwi',
#  'kim',
#  'kimimoto',
#  'kira',
#  'kiwikaiser',
#  'kl_alcatrazz',
#  'klehm',
#  'klein',
#  'kngrsch',
#  'knollmann',
#  'konrad',
#  'konstantin',
#  'kosarev',
#  'koschel',
#  'kovacic',
#  'koziol',
#  'krein',
#  'krissi',
#  'kristijan',
#  'kristin',
#  'kruse',
#  'kueck',
#  'kuhle',
#  'kunig',
#  'kunkel',
#  'kunz',
#  'kupka',
#  'kurt',
#  'köhler',
#  'könige',
#  'kılıç',
#  'laier',
#  'landen',
#  'lange',
#  'lani',
#  'lariii',
#  'larissa',
#  'larry',
#  'lars',
#  'laufen',
#  'laura',
#  'lauraa',
#  'lea',
#  'lee',
#  'lehmann',
#  'leistungssport',
#  'lena',
#  'lene',
#  'lennart',
#  'lennert',
#  'leocrafter',
#  'leon',
#  'lewi',
#  'lieblingsfehler',
#  'liebold',
#  'lifewithphilipp',
#  'lilly',
#  'lin',
#  'lina',
#  'linahd',
#  'lindloff',
#  'lindmann',
#  'line',
#  'lisa',
#  'lisanne',
#  'little',
#  'littlemissbee',
#  'livia',
#  'lmmrs',
#  'lol',
#  'lombardo',
#  'lordlp',
#  'lorena',
#  'lores',
#  'lori_glorii',
#  'loritz',
#  'loscheider',
#  'luca',
#  'lucas',
#  'lucy',
#  'ludwig',
#  'luisa',
#  'luisλ',
#  'luk',
#  'lukas',
#  'löw',
#  'löwenkind',
#  'lümmelchen',
#  'm4rc3l146',
#  'maaß',
#  'maike',
#  'maja',
#  'mal',
#  'malek',
#  'manja',
#  'manko',
#  'marc',
#  'marcel',
#  'marco',
#  'marcus',
#  'maren',
#  'maria',
#  'marie',
#  'mario',
#  'marissa',
#  'mark',
#  'markus',
#  'marleen',
#  'mart',
#  'martin',
#  'martín',
#  'matthias',
#  'maureen',
#  'maurer',
#  'mauritz',
#  'max',
#  'maximilian',
#  'maxizzle',
#  'mayo',
#  'meier',
#  'melanie',
#  'melina',
#  'melissa',
#  'memory',
#  'mensen',
#  'ment0r',
#  'menzler',
#  'meraderhd',
#  'merigold',
#  'merle',
#  'mia',
#  'michael',
#  'michelle_apeee',
#  'midnightfeger',
#  'midoriya',
#  'mila',
#  'milou',
#  'mirai',
#  'miri',
#  'mirzet',
#  'missb',
#  'mom',
#  'moment',
#  'momotv',
#  'monami',
#  'monika',
#  'monique',
#  'moritz',
#  'motte',
#  'mr',
#  'mrs',
#  'muffin',
#  'mura',
#  'murat',
#  'murie',
#  'my',
#  'myung',
#  'mändy',
#  'mértine',
#  'mödinger',
#  'möwius',
#  'müller',
#  'na',
#  'nadine',
#  'naka',
#  'nancy',
#  'nano',
#  'nasouf',
#  'nathalie',
#  'natsuai',
#  'negroni',
#  'neizert',
#  'nekos',
#  'nena',
#  'nessi',
#  'neumann',
#  'nicieza',
#  'nick',
#  'nicki',
#  'nicklas',
#  'nicky',
#  'nico',
#  'nicolas',
#  'nicole',
#  'niklas',
#  'nikushka',
#  'nils',
#  'nina',
#  'nit',
#  'niña',
#  'nobody',
#  'nock',
#  'noedel',
#  'noobly',
#  'nurderbvb',
#  'nympha',
#  'ocked',
#  'ocko',
#  'oderso',
#  'oetteken',
#  'offenbeach',
#  'okcan',
#  'oliver',
#  'olivia',
#  'ollie',
#  'orangeguguʕ',
#  'osayio',
#  'ott',
#  'pa',
#  'palazzini',
#  'pamuk',
#  'panda',
#  'papenburg',
#  'pari',
#  'passek',
#  'patrick',
#  'paul',
#  'paulsen',
#  'peisker',
#  'pencil',
#  'perm',
#  'peter',
#  'petersdorf',
#  'petoyusa',
#  'petra',
#  'phelps',
#  'philip',
#  'philipp',
#  'pia',
#  'pielnik',
#  'pieper',
#  'pierre',
#  'plieninger',
#  'plop',
#  'pohl',
#  'pop',
#  'prinzaffe',
#  'prokisch',
#  'puma',
#  'pups',
#  'purpose',
#  'quit',
#  'radek',
#  'radke',
#  'radoš',
#  'radschun',
#  'raheb',
#  'rainbow',
#  'ralf',
#  'ramiyo',
#  'ramona',
#  'rapi',
#  'raptorendame',
#  'rauchfuß',
#  'rave',
#  'rebecca',
#  'rebellionsplash',
#  'reineke',
#  'reinhard',
#  'reiser',
#  'rené',
#  'reuther',
#  'rieger',
#  'ries',
#  'rigo',
#  'rinke',
#  'robert',
#  'roberto',
#  'robin',
#  'rogler',
#  'roland',
#  'roman',
#  'romeike',
#  'romiina',
#  'rommy',
#  'romy',
#  'ronja',
#  'rosanna',
#  'ross',
#  'rothe',
#  'rwo',
#  's_nator',
#  'sabine',
#  'sablne',
#  'sabrina',
#  'sabriye',
#  'sahintürk',
#  'sahra',
#  'saka',
#  'salvatore',
#  'samantha',
#  'samira',
#  'sampletext',
#  'samuel',
#  'sandra',
#  'sarah',
#  'sarima',
#  'sascha',
#  'saša',
#  'scandrett',
#  'schenke',
#  'scherer',
#  'scherpe',
#  'scherzberg',
#  'schirin',
#  'schirmer',
#  'schlattmann',
#  'schmidt',
#  'schmied',
#  'schmitz',
#  'schneider',
#  'schoettelkotte',
#  'scholz',
#  'schröder',
#  'schukmann',
#  'schulte',
#  'schultz',
#  'schulz',
#  'schulze',
#  'schumacher',
#  'schwind',
#  'sebastian',
#  'sebeck',
#  'sef',
#  'seidensockensammler',
#  'seifert',
#  'selferus',
#  'selichan',
#  'seryoga',
#  'sesena',
#  'sgt',
#  'shaddix',
#  'siegfried',
#  'sieglinde',
#  'siemens',
#  'siewert',
#  'silvie',
#  'simon',
#  'sirin',
#  'skenia',
#  'skipper',
#  'skynet',
#  'slimani',
#  'slizzer',
#  'slr',
#  'slurpee',
#  'smilla',
#  'sofferle',
#  'sofi',
#  'sophia',
#  'sophie',
#  'specht',
#  'spin',
#  'spitzname',
#  'sporleder',
#  'stadlmeyr',
#  'stauder',
#  'stefan',
#  'stefanie',
#  'steffen',
#  'steffi',
#  'steinert',
#  'stephan',
#  'stephanie',
#  'stetter',
#  'steven',
#  'sti',
#  'stiens',
#  'storm',
#  'stosch',
#  'stoye',
#  'stutzenberger',
#  'style',
#  'styles',
#  'susana',
#  'susanne',
#  'susi',
#  'sutschet',
#  'svend',
#  'svenja',
#  'tanisha',
#  'tanja',
#  'taps',
#  'tareef',
#  'tatjana',
#  'tauchnitz',
#  'teaaamkayef',
#  'teller',
#  'teresa',
#  'tesa',
#  'teuber',
#  'theißen',
#  'theofficialcaud',
#  'theresa',
#  'therpunkt',
#  'thomas',
#  'til',
#  'tim',
#  'timmy',
#  'timo',
#  'timurkenpachi',
#  'tina',
#  'titoo',
#  'tobi',
#  'tobias',
#  'tom',
#  'toniiitimeless',
#  'torben',
#  'total',
#  'touri',
#  'trace',
#  'traugott',
#  'tro',
#  'turconi',
#  'twistedfranz',
#  'uhl',
#  'urbanietz',
#  'vadim',
#  'van',
#  'vanessa',
#  'vanill3eis',
#  'vanny',
#  'vany',
#  'vanypradshaw',
#  'vapor',
#  'veda',
#  'verein',
#  'verena',
#  'verl',
#  'viktor',
#  'vincent',
#  'vipstar',
#  'virgallita',
#  'virtualmarc',
#  'vittorio',
#  'vivian',
#  'vogt',
#  'vollmer',
#  'von',
#  'voymar',
#  'vucic',
#  'wackes',
#  'waffel',
#  'waldemar',
#  'wamppy',
#  'wassam',
#  'weber',
#  'weibel',
#  'weigel',
#  'weisshaar',
#  'weiß',
#  'wendy',
#  'werner',
#  'wiedermann',
#  'willenborg',
#  'williamson',
#  'wingefeld',
#  'wirtz',
#  'wolf',
#  'wolfgang',
#  'wolwery',
#  'wookie_liebt_euch',
#  'wormuth',
#  'wrangler',
#  'wunderlich',
#  'wölfin',
#  'xd',
#  'yasmin',
#  'yavor',
#  'yemina',
#  'youssef',
#  'za',
#  'zeeza',
#  'zeidler',
#  'zeimi',
#  'zenner',
#  'zentner',
#  'zeynep',
#  'ziemiak',
#  'zimmermann',
#  'zscherp',
#  'zühal_',
#  'алина',
#  'вαтмαη',
#  'ᴰᴱᴬᴾ',
#  'ᵈᵒʷᶰʰᶤˡˡ',
#  'ᵈᵘᵈᵉ',
#  'えいき',
#  'つn',
#  'デイビッド',
#  'ペトユサ']

# %%
bayes_names = bayes()
bayes_names.fit(x_trainSub_names, y_trainSub)
# Out:
# MultinomialNB()

# %%
nameScore = bayes_names.score(x_test_names, y_test)
nameScore_text = "Name Score is {:0.2%}".format(nameScore)
print(nameScore_text)
# Out:
# Name Score is 63.19%

# %%
stacked_input2 = pd.Series(bayes_names.predict(x_trainMeta_names))
stacked_input2_test = pd.Series(bayes_names.predict(x_test_names))

# %%
# 3. Build a meta classifier that combines the previously built classifiers based on their age classes (0-10, 11-20, 21-30, 31+)

# Now we use the stacks as input for our Meta Classifier

# %%
# Build a pandas df for training
meta_data_train = {'input1': stacked_input1, 'input2': stacked_input2}
meta_data_train = pd.DataFrame(meta_data_train)
meta_data_train.head(10)
# Out:
#    input1  input2
# 0       1       1
# 1       1       1
# 2       1       1
# 3       1       1
# 4       1       2
# 5       1       1
# 6       1       1
# 7       1       1
# 8       1       1
# 9       1       1

# %%
# Build a pandas df for test
meta_data_test = {'input1': stacked_input1_test, 'input2': stacked_input2_test}
meta_data_test = pd.DataFrame(meta_data_test)
meta_data_test.head(10)
# Out:
#    input1  input2
# 0       2       1
# 1       1       1
# 2       1       1
# 3       1       1
# 4       1       1
# 5       1       1
# 6       1       1
# 7       1       1
# 8       1       1
# 9       1       1

# %%
# Train the Meta Classifier 
forest = RandomForestClassifier()
forest.fit(meta_data_train, y_trainMeta)
# Out:
# RandomForestClassifier()

# %%
# Evaluate the Meta Classifier on the test set and compare to previous results
metaScore = forest.score(meta_data_test, y_test)
metaScore_text = "Meta Score is {:0.2%}".format(metaScore)
print(tweetScore_text)
print(nameScore_text)
print(metaScore_text)
# Out:
# Tweet SCore is 65.38%
# Name Score is 63.19%
# Meta Score is 67.03%
